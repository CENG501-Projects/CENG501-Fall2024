# %%
from google.colab import drive
drive.mount('/content/drive')

import wandb
wandb.login(key="yourpersonalwandbkeyhere")

# skip if cloned already
# !git clone https://github.com/state-spaces/s4.git /content/drive/MyDrive/ceng501/codes/s4-main

# %cd /content/drive/MyDrive/ceng501/codes/s4-main
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: sevvalucar (sevvalucar-middle-east-technical-university). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# /content/drive/MyDrive/ceng501/codes/s4-main
# assets	      configs	  extensions   Makefile   outputs      requirements-dev.txt  train.py
# CHANGELOG.md  data	  generate.py  models	  __pycache__  requirements.txt
# checkpoints   example.py  LICENSE      notebooks  README.md    src

# %%
# !pip install -r requirements.txt

# %%
# !pip3 uninstall --yes torch torchaudio torchvision torchtext torchdata
# !pip3 install torch==2.3.0 torchaudio torchvision torchtext==0.18.0 torchdata

# %%
# first epoch
# !python -m train experiment=lra/old/transformer-lra-aan

# %%
# load from checkpoint
# !python -u -m train experiment=lra/old/transformer-lra-aan-sampled train.ckpt=/path/to/checkpoint/last.ckpt

# %%
wandb.finish()
